# %% [markdown]
# IMPORTING ALL REQUIRED LIBRARIES ____________

# %%
import pandas as pd  
import numpy as np
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# LOADING DATASET ________________________

# %%
df=pd.read_csv('baseball.csv')
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %% [markdown]
# CHECK INFORMATION FROM DATASET___________________

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %%
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %%
df.shape
# Out:
# (30, 17)

# %%
df.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %%
df=df.astype({'ERA':'int'})
df.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER  ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601    3   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653    4   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584    3  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643    3   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746    4   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %%
df.dtypes
# Out:
# W      int64
# R      int64
# AB     int64
# H      int64
# 2B     int64
# 3B     int64
# HR     int64
# BB     int64
# SO     int64
# SB     int64
# RA     int64
# ER     int64
# ERA    int64
# CG     int64
# SHO    int64
# SV     int64
# E      int64
# dtype: object

# %%
plt.figure(figsize=(14,12))
sns.heatmap(df.corr(),annot=True,annot_kws={"size":12},cmap='summer',vmin=-1.0,vmax=1.0)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.show()

# %%
x=df.drop('W',axis=1)
y=df['W']

# %%
x.head()
# Out:
#      R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER  ERA  CG  SHO  SV  \
# 0  724  5575  1497  300  42  139  383   973  104  641  601    3   2    8  56
# 1  696  5467  1349  277  44  156  439  1264   70  700  653    4   2   12  45
# 2  669  5439  1395  303  29  141  533  1157   86  640  584    3  11   10  38
# 3  622  5533  1381  260  27  136  404  1231   68  701  643    3   7    9  37
# 4  689  5605  1515  289  49  151  455  1259   83  803  746    4   7   12  35
#
#      E
# 0   88
# 1   86
# 2   79
# 3  101
# 4   86

# %%
y.head()
# Out:
# 0    95
# 1    83
# 2    81
# 3    76
# 4    74
# Name: W, dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
lg=LinearRegression()

# %%
lg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
print(f"Regression :{lg.score(x_test,y_test)}")
# Out:
# Regression :0.6686955846435662

# %%
y_pred=lg.predict(x_test)

# %%
y_pred
# Out:
# array([ 83.75990045, 106.18538293,  69.5805588 ,  97.16319467,
#         93.86795302,  79.28186761])

# %%
import pickle
filename='baseball.pkl'
pickle.dump(lg,open(filename,'wb'))

# %%
load_model=pickle.load(open('baseball.pkl','rb'))
result=load_model.score(x_test,y_test)
print(result*100)
# Out:
# 66.86955846435661

# %%
resultset=pd.DataFrame([load_model.predict(x_test)[:],y_pred[:]],index=['Predicted','Original'])
resultset
# Out:
#                  0           1          2          3          4          5
# Predicted  83.7599  106.185383  69.580559  97.163195  93.867953  79.281868
# Original   83.7599  106.185383  69.580559  97.163195  93.867953  79.281868
